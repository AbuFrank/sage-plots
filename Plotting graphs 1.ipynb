# %%
from sage.interfaces.phc import *
circle((1,1), 1) + plot(x^2, (x,0,5))
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
from sage.interfaces.phc import *
circle((1,1), 1) + plot(x^2, (x,0,5))
# Out:
# Graphics object consisting of 2 graphics primitives
